# %% [markdown]
# # Description

# %% [raw]
# - Using nltk importing stopwords and we can remove stop words for speed.
# - cosine_distance helps to find the similarity between two vectors.
# - networkx is used for the creation, manipulation, and study of complex networks or graphs.
# - reading the text files.
# - step-2 to find similarity between two sentences.
# - build the vector for the first sentence.
# - build the vector for the second sentence.
# - Step 3 - Rank sentences in similarity martix.
# - Finish off by printing summary.

# %%
#you can remove stop words for speed
from nltk.corpus import stopwords 
# Helps to find the similarity between two vectors.
from nltk.cluster.util import cosine_distance 
import numpy as np
# used for the creation, manipulation, and study of complex networks or graphs.
import networkx as nx

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\pavan\anaconda3\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\pavan\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\pavan\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\pavan\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\pavan\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\pavan\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\pavan\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\pavan\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pavan\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\pavan\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.0)

# %%
import spacy

# !python -m spacy download fr_core_news_sm
# !python -m spacy download de_core_news_sm
# !python -m spacy download es_core_news_sm


nlp_french = spacy.load("fr_core_news_sm")
nlp_german = spacy.load("de_core_news_sm")
nlp_spanish = spacy.load("es_core_news_sm")


# Define the list of file paths
textfiles = [
    r'C:\Users\pavan\Documents\French.txt',
    r"C:\Users\pavan\Documents\german.txt",
    r"C:\Users\pavan\Documents\spanish.txt",
]

# Create lists to hold sentences for each file
sentences_lists = [[] for _ in range(len(textfiles))]

# Function to tokenize sentences and identify language using spaCy
def tokenize_sentences_and_identify_language(text, nlp):
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    language = doc.lang_
    return sentences, language

# Loop through each file and tokenize sentences
for index, filepath in enumerate(textfiles):
    with open(filepath, "r", encoding="utf-8") as file:
        filedata = file.readline().strip()  # Read only the first line (paragraph)
        sentences, language = tokenize_sentences_and_identify_language(filedata, 
                                                                       nlp_french 
                                                                       if "French" in filepath 
                                                                       else (nlp_german 
                                                                       if "german" in filepath 
                                                                       else nlp_spanish))
        sentences_lists[index].extend(sentences)
        print(f"Language identified for {filepath}: {language}")

# Print the sentences for each file
for index, sentences in enumerate(sentences_lists):
    print(f"\nSentences for file {textfiles[index]}:")
    for sentence in sentences:
        print(sentence)
# Out:
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#      --------------------------------------- 0.0/16.3 MB 487.6 kB/s eta 0:00:34
#      --------------------------------------- 0.1/16.3 MB 544.7 kB/s eta 0:00:30
#      --------------------------------------- 0.1/16.3 MB 435.7 kB/s eta 0:00:38
#      --------------------------------------- 0.1/16.3 MB 435.7 kB/s eta 0:00:38
#      --------------------------------------- 0.1/16.3 MB 479.3 kB/s eta 0:00:34
#      --------------------------------------- 0.2/16.3 MB 731.4 kB/s eta 0:00:22
#       --------------------------------------- 0.4/16.3 MB 1.1 MB/s eta 0:00:15
#      - -------------------------------------- 0.6/16.3 MB 1.6 MB/s eta 0:00:10
#      -- ------------------------------------- 1.1/16.3 MB 2.8 MB/s eta 0:00:06
#      ---- ----------------------------------- 1
MB/s eta 0:00:01
#      ---------------------- ----------------- 7.2/12.9 MB 7.2 MB/s eta 0:00:01
#      ------------------------ --------------- 8.0/12.9 MB 7.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.9 MB 8.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.3/12.9 MB 8.2 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.9 MB 8.6 MB/s eta 0:00:01
#      --------------------------------- ----- 11.2/12.9 MB 10.6 MB/s eta 0:00:01
#      ----------------------------------- --- 11.8/12.9 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.9 MB 11.1 MB/s eta 0:00:01
#      --------------------------------------  12.9/12.9 MB 11.1 MB/s eta 0:00:01
#      --------------------------------------- 12.9/12.9 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\pavan\anaconda3\lib\site-packages (from es-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\pavan\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: language-data>=1.2 in c:\users\pavan\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\pavan\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\pavan\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\pavan\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\pavan\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\pavan\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\pavan\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pavan\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\pavan\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# Language identified for C:\Users\pavan\Documents\French.txt: fr
# Language identified for C:\Users\pavan\Documents\german.txt: de
# Language identified for C:\Users\pavan\Documents\spanish.txt: es
#
# Sentences for file C:\Users\pavan\Documents\French.txt:
# Le soleil se lève à l'horizon, éclairant doucement la terre qui s'éveille.
#
# Sentences for file C:\Users\pavan\Documents\german.txt:
# Die Sonne bricht langsam über den Horizont, erleuchtet die Welt in goldenem Licht.
#
# Sentences for file C:\Users\pavan\Documents\spanish.txt:
# El sol se eleva en el horizonte, disipando las sombras de la noche.
# Las aves comienzan a cantar, llenando el aire con sus melodías alegres.
# Una brisa suave acaricia la piel, trayendo consigo un soplo de frescura.
# Las flores despiertan de su sueño, abriendo sus pétalos al nuevo día.
# En las calles, la vida comienza a palpitar, con gente que se prepara para el día que empieza.
# El aroma del café flota en el aire, invitando a despertar los sentidos.
# Los niños salen a jugar, corriendo y riendo bajo el cielo despejado.
# En los campos, los agricultores trabajan la tierra, sembrando semillas de esperanza.
# El murmullo de los arroyos acompaña el amanecer, cantando una canción eterna.
# En la ciudad, las luces se encienden poco a poco, iluminando el camino de aquellos que madrugan.
# El día se extiende ante nosotros, lleno de posibilidades y oportunidades.
# Las horas pasan lentamente, marcadas por el ritmo tranquilo de la vida.
# La gente se reúne en los parques, disfrutando del sol y la compañía de los demás.
# En las plazas, la música llena el aire, creando un ambiente festivo y alegre.
# Los comerciantes preparan sus puestos, exhibiendo sus productos con orgullo.
# En las playas, el mar brilla bajo el sol, invitando a nadar y relajarse.
# Las montañas se recortan contra el cielo azul, majestuosas y eternas en su grandeza.
# La ciudad bulle de actividad, con gente que va y viene sin descanso.
# Las risas y conversaciones llenan los cafés, creando un ambiente acogedor y familiar.
# En los hogares, las familias se reúnen para compartir comidas y momentos especiales.
# El amor y la amistad llenan el aire, haciendo que cada día sea único y especial.
# La noche cae suavemente, cubriendo el mundo con un manto de estrellas.
# Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.
# Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.

# %%
sentences_lists
# Out:
# [["Le soleil se lève à l'horizon, éclairant doucement la terre qui s'éveille."],
#  ['Die Sonne bricht langsam über den Horizont, erleuchtet die Welt in goldenem Licht.'],
#  ['El sol se eleva en el horizonte, disipando las sombras de la noche.',
#   'Las aves comienzan a cantar, llenando el aire con sus melodías alegres.',
#   'Una brisa suave acaricia la piel, trayendo consigo un soplo de frescura.',
#   'Las flores despiertan de su sueño, abriendo sus pétalos al nuevo día.',
#   'En las calles, la vida comienza a palpitar, con gente que se prepara para el día que empieza.',
#   'El aroma del café flota en el aire, invitando a despertar los sentidos.',
#   'Los niños salen a jugar, corriendo y riendo bajo el cielo despejado.',
#   'En los campos, los agricultores trabajan la tierra, sembrando semillas de esperanza.',
#   'El murmullo de los arroyos acompaña el amanecer, cantando una canción eterna.',
#   'En la ciudad, las luces se encienden poco a poco, iluminando el camino de aquellos que madrugan.',
#   'El día se extiende ante nosotros, lleno de posibilidades y oportunidades.',
#   'Las horas pasan lentamente, marcadas por el ritmo tranquilo de la vida.',
#   'La gente se reúne en los parques, disfrutando del sol y la compañía de los demás.',
#   'En las plazas, la música llena el aire, creando un ambiente festivo y alegre.',
#   'Los comerciantes preparan sus puestos, exhibiendo sus productos con orgullo.',
#   'En las playas, el mar brilla bajo el sol, invitando a nadar y relajarse.',
#   'Las montañas se recortan contra el cielo azul, majestuosas y eternas en su grandeza.',
#   'La ciudad bulle de actividad, con gente que va y viene sin descanso.',
#   'Las risas y conversaciones llenan los cafés, creando un ambiente acogedor y familiar.',
#   'En los hogares, las familias se reúnen para compartir comidas y momentos especiales.',
#   'El amor y la amistad llenan el aire, haciendo que cada día sea único y especial.',
#   'La noche cae suavemente, cubriendo el mundo con un manto de estrellas.',
#   'Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.',
#   'Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.']]

# %%
for i in range(len(sentences_lists)):
    print(f'-------------Text{i}--------------')
    print(' '*10)
    print(sentences_lists[i])
    print(' '*10)
# Out:
# -------------Text0--------------
#
# ["Le soleil se lève à l'horizon, éclairant doucement la terre qui s'éveille."]
#
# -------------Text1--------------
#
# ['Die Sonne bricht langsam über den Horizont, erleuchtet die Welt in goldenem Licht.']
#
# -------------Text2--------------
#
# ['El sol se eleva en el horizonte, disipando las sombras de la noche.', 'Las aves comienzan a cantar, llenando el aire con sus melodías alegres.', 'Una brisa suave acaricia la piel, trayendo consigo un soplo de frescura.', 'Las flores despiertan de su sueño, abriendo sus pétalos al nuevo día.', 'En las calles, la vida comienza a palpitar, con gente que se prepara para el día que empieza.', 'El aroma del café flota en el aire, invitando a despertar los sentidos.', 'Los niños salen a jugar, corriendo y riendo bajo el cielo despejado.', 'En los campos, los agricultores trabajan la tierra, sembrando semillas de esperanza.', 'El murmullo de los arroyos acompaña el amanecer, cantando una canción eterna.', 'En la ciudad, las luces se encienden poco a poco, iluminando el camino de aquellos que madrugan.', 'El día se extiende ante nosotros, lleno de posibilidades y oportunidades.', 'Las horas pasan lentamente, marcadas por el ritmo tranquilo de la vida.', 'La gente se reúne en los parques, disfrutando del sol y la compañía de los demás.', 'En las plazas, la música llena el aire, creando un ambiente festivo y alegre.', 'Los comerciantes preparan sus puestos, exhibiendo sus productos con orgullo.', 'En las playas, el mar brilla bajo el sol, invitando a nadar y relajarse.', 'Las montañas se recortan contra el cielo azul, majestuosas y eternas en su grandeza.', 'La ciudad bulle de actividad, con gente que va y viene sin descanso.', 'Las risas y conversaciones llenan los cafés, creando un ambiente acogedor y familiar.', 'En los hogares, las familias se reúnen para compartir comidas y momentos especiales.', 'El amor y la amistad llenan el aire, haciendo que cada día sea único y especial.', 'La noche cae suavemente, cubriendo el mundo con un manto de estrellas.', 'Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.', 'Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.']

# %%
# step-2 to find similarity between two sentences 
def sentence_similarity(sent1, sent2 ):
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
    all_words = list(set(sent1 + sent2))
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
    # build the vector for the first sentence
    for w in sent1:
        vector1[all_words.index(w)] += 1
        # build the vector for the second sentence
    for w in sent2:
        vector2[all_words.index(w)] += 1
    return 1 - cosine_distance(vector1, vector2)

# %%
similarity=[]
for i in sentences_lists:
    similarity_matrix = np.zeros((len(i), len(i)))
    for idx1 in range(len(i)):
        for idx2 in range(len(i)):
            if idx1 == idx2: #ignore if both are same sentences
                continue
            similarity_matrix[idx1][idx2] = sentence_similarity(i[idx1], i[idx2])
    similarity.append(similarity_matrix)

# %%
similarity
# Out:
# [array([[0.]]),
#  array([[0.]]),
#  array([[0.        , 0.9401792 , 0.88509804, 0.939831  , 0.88817461,
#          0.95015131, 0.94350922, 0.9167223 , 0.86454051, 0.91828903,
#          0.93784044, 0.89136936, 0.96442481, 0.93256369, 0.86688726,
#          0.88497471, 0.90738841, 0.89204179, 0.91843629, 0.92983169,
#          0.9139579 , 0.92103765, 0.97102352, 0.90281761],
#         [0.9401792 , 0.        , 0.92941311, 0.91595798, 0.9313709 ,
#          0.94540508, 0.90007496, 0.9597311 , 0.94815316, 0.93116129,
#          0.86353468, 0.94506686, 0.93463288, 0.96916021, 0.8246274 ,
#          0.93518624, 0.96483367, 0.89131233, 0.96718973, 0.9413977 ,
#          0.95161384, 0.9228616 , 0.91548223, 0.93846842],
#         [0.88509804, 0.92941311, 0.        , 0.91960636, 0.90869777,
#          0.92457071, 0.91796491, 0.93552164, 0.92365381, 0.9231637 ,
#          0.84664095, 0.9306534 , 0.88772237, 0.91435425, 0.88872656,
#          0.90603334, 0.92778015, 0.89197106, 0.96492244, 0.92544391,
#          0.92418273, 0.87482227, 0.88107704, 0.95337467],
#         [0.939831  , 0.91595798, 0.91960636, 0.        , 0.8714185 ,
#          0.93250295, 0.91415468, 0.92354845, 0.84969151, 0.89796172,
#          0.92565066, 0.89601138, 0.96206412, 0.8917251 , 0.91061682,
#          0.94373195, 0.88995477, 0.90836935, 0.92451677, 0.94046279,
#          0.85103677, 0.93894522, 0.91975859, 0.96765396, 0.75267188,
#          0.93629977, 0.90787397, 0.92883859, 0.93202463, 0.9089524 ,
#          0.        , 0.89234379, 0.86735641, 0.96530876],
#         [0.92103765, 0.9228616 , 0.87482227, 0.88881637, 0.87065435,
#          0.90880343, 0.88963738, 0.8712798 , 0.92778323, 0.94987283,
#          0.89031736, 0.86676231, 0.92502239, 0.90958964, 0.85208931,
#          0.81380786, 0.91799759, 0.91627565, 0.90031085, 0.87643208,
#          0.89234379, 0.        , 0.8878514 , 0.90426524],
#         [0.97102352, 0.91548223, 0.88107704, 0.96268869, 0.83814655,
#          0.91502225, 0.94203431, 0.90261688, 0.83552754, 0.90415281,
#          0.93455477, 0.86283855, 0.95686586, 0.88666461, 0.8988603 ,
#          0.86387682, 0.89688992, 0.86322587, 0.90359202, 0.91334156,
#          0.86735641, 0.8878514 , 0.        , 0.87101399],
#         [0.90281761, 0.93846842, 0.95337467, 0.88854362, 0.93482759,
#          0.93417526, 0.91438888, 0.89567469, 0.91236272, 0.94454901,
#          0.87856618, 0.91088422, 0.90536867, 0.934777  , 0.81836473,
#          0.88713744, 0.91505019, 0.95640974, 0.94718672, 0.9068389 ,
#          0.96530876, 0.90426524, 0.87101399, 0.        ]])]

# %%
# Step 3 - Rank sentences in similarity martix
score=[]
for i in similarity:
    sentence_similarity_graph = nx.from_numpy_array(i)
    scores = nx.pagerank(sentence_similarity_graph)
    score.append(scores)

# %%
score
# Out:
# [{0: 1.0},
#  {0: 1.0},
#  {0: 0.04216683476889179,
#   1: 0.042654771628178406,
#   2: 0.04200259336498004,
#   3: 0.041777984278188435,
#   4: 0.04130469649293941,
#   5: 0.042593631407275415,
#   6: 0.04156037675281019,
#   7: 0.042112534522930116,
#   8: 0.04134434416335089,
#   9: 0.041842316505830035,
#   10: 0.04052024570672929,
#   11: 0.04183030888161961,
#   12: 0.042206077275796755,
#   13: 0.04223906968119704,
#   14: 0.039009196362349834,
#   15: 0.04089843851720168,
#   16: 0.04208518737194219,
#   17: 0.04068747275102881,
#   18: 0.04237444024230949,
#   19: 0.04192175232668565,
#   20: 0.042029715509244656,
#   21: 0.04130540541025096,
#   22: 0.04147088418785383,
#   23: 0.04206172189041523}]

# %%
ranked_sentences = []
for sentence_list in sentences_lists:
    ranked_sentence = sorted(((score, sentence) for score, sentence in zip(scores, sentence_list)), reverse=True)
    ranked_sentences.append(ranked_sentence)

# %%
ranked_sentences
# Out:
# [[(0,
#    "Le soleil se lève à l'horizon, éclairant doucement la terre qui s'éveille.")],
#  [(0,
#    'Die Sonne bricht langsam über den Horizont, erleuchtet die Welt in goldenem Licht.')],
#  [(23,
#    'Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.'),
#   (22,
#    'Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.'),
#   (21,
#    'La noche cae suavemente, cubriendo el mundo con un manto de estrellas.'),
#   (20,
#    'El amor y la amistad llenan el aire, haciendo que cada día sea único y especial.'),
#   (19,
#    'En los hogares, las familias se reúnen para compartir comidas y momentos especiales.'),
#   (18,
#    'Las risas y conversaciones llenan los cafés, creando un ambiente acogedor y familiar.'),
#   (17, 'La ciudad bulle de actividad, con gente que va y viene sin descanso.'),
#   (16,
#    'Las montañas se recortan contra el cielo azul, majestuosas y eternas en su grandeza.'),
#   (15,
#    'En las playas, el mar brilla bajo el sol, invitando a nadar y relajarse.'),
#   (14,
#    'Los comerciantes preparan sus puestos, exhibiendo sus productos con orgullo.'),
#   (13,
#    'En las plazas, la música llena el aire, creando un ambiente festivo y alegre.'),
#   (12,
#    'La gente se reúne en los parques, disfrutando del sol y la compañía de los demás.'),
#   (11,
#    'Las horas pasan lentamente, marcadas por el ritmo tranquilo de la vida.'),
#   (10,
#    'El día se extiende ante nosotros, lleno de posibilidades y oportunidades.'),
#   (9,
#    'En la ciudad, las luces se encienden poco a poco, iluminando el camino de aquellos que madrugan.'),
#   (8,
#    'El murmullo de los arroyos acompaña el amanecer, cantando una canción eterna.'),
#   (7,
#    'En los campos, los agricultores trabajan la tierra, sembrando semillas de esperanza.'),
#   (6, 'Los niños salen a jugar, corriendo y riendo bajo el cielo despejado.'),
#   (5,
#    'El aroma del café flota en el aire, invitando a despertar los sentidos.'),
#   (4,
#    'En las calles, la vida comienza a palpitar, con gente que se prepara para el día que empieza.'),
#   (3, 'Las flores despiertan de su sueño, abriendo sus pétalos al nuevo día.'),
#   (2,
#    'Una brisa suave acaricia la piel, trayendo consigo un soplo de frescura.'),
#   (1,
#    'Las aves comienzan a cantar, llenando el aire con sus melodías alegres.'),
#   (0, 'El sol se eleva en el horizonte, disipando las sombras de la noche.')]]

# %%
# Finish off by printing summary.

for i in ranked_sentences:
    n = int(input("How many sentences do you want in the summary? "))
  
    for i in range(n):
        print("".join(ranked_sentence[i][1]))
# Out:
# How many sentences do you want in the summary? 3
# Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.
# Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.
# La noche cae suavemente, cubriendo el mundo con un manto de estrellas.
# How many sentences do you want in the summary? 4
# Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.
# Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.
# La noche cae suavemente, cubriendo el mundo con un manto de estrellas.
# El amor y la amistad llenan el aire, haciendo que cada día sea único y especial.
# How many sentences do you want in the summary? 6
# Y así, el ciclo de la vida continúa, con cada día que trae consigo nuevas experiencias y aprendizajes.
# Los sueños nos llevan a lugares lejanos, donde todo es posible y nada es imposible.
# La noche cae suavemente, cubriendo el mundo con un manto de estrellas.
# El amor y la amistad llenan el aire, haciendo que cada día sea único y especial.
# En los hogares, las familias se reúnen para compartir comidas y momentos especiales.
# Las risas y conversaciones llenan los cafés, creando un ambiente acogedor y familiar.
